# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
tips.iloc[2:3]
# Out:
#    total_bill  tip   sex smoker  day    time  size
# 2       21.01  3.5  Male     No  Sun  Dinner     3

# %%
tips.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 tips.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
tips.describe()

# %%
pip install notebook

# %%
tips.corr()

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='smoker', data=tips, hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.catplot(x='sex',data=tips,hue='smoker',col='day',kind='count')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue='size',palette='rocket')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue='day',palette='viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue='sex',palette='viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(y='total_bill',data=tips,color='green')
# Out:
# <Axes: ylabel='total_bill'>

# %%
ax = sns.boxplot(y='total_bill',data=tips,color='green')
ax.set_yticks(np.arange(0,50,2))
ax.grid(True)

# %%
ax = sns.boxplot(y='tip',data=tips,color='green')
ax.set_yticks(np.arange(0,10,0.001))
ax.grid(True)

# %%
sns.lineplot(x='size', y='tip',data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(x='total_bill', y='size',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.lineplot(x='size', y='total_bill',data=tips)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.lineplot(x='size', y='total_bill',data=tips,hue='sex')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips,hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='time',data=tips,hue='day')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
